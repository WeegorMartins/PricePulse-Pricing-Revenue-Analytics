# %% [markdown]
# # 05 — Price-Volume-Mix

# %% [markdown]
# Run `python src/run_pvm.py` first. The decomposition must reconcile.

# %%
import pandas as pd
from config.settings import PROCESSED_DIR
pvm = pd.read_parquet(PROCESSED_DIR / 'pvm_summary.parquet')
pvm
