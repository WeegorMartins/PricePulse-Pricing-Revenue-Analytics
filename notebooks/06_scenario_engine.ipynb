# %% [markdown]
# # 06 — Scenario Engine

# %% [markdown]
# Run `python src/run_scenarios.py` first.

# %%
import pandas as pd
from config.settings import PROCESSED_DIR
sc = pd.read_parquet(PROCESSED_DIR / 'scenario_grid.parquet')
sc.head()
