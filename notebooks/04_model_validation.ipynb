# %% [markdown]
# # 04 — Model Validation

# %% [markdown]
# Compare coefficient sign, magnitude, intervals and specification sensitivity.

# %%
import pandas as pd
from config.settings import PROCESSED_DIR
el = pd.read_parquet(PROCESSED_DIR / 'elasticity_models.parquet')

# %%
el[['item_id','baseline_estimate','twfe_estimate','ppml_estimate','twfe_ci_low','twfe_ci_high','model_gap','evidence_class']].head(20)
